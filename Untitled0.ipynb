# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoguilhermenunes2009-afk/Aula-01-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
valor_1 = 12
valor_2 = 6
resultado = valor_1 + valor_2
subtracao = valor_1 - valor_2
multiplicacao = valor_1 * valor_2
divisao = valor_1 / valor_2
potenciacao = valor_1 ** valor_2
print (f'o resultado vai ser: {resultado}')
print (f'o resultado vai ser: {subtracao}')
print (f'o resultado vai ser: {multiplicacao}')
print (f'o resultado vai ser: {potenciacao}')
# Out:
# o resultado vai ser: 18
# o resultado vai ser: 6
# o resultado vai ser: 72
# o resultado vai ser: 2985984

# %%
valor_1 = 7
valor_2 = 2
resultado = valor_1 + valor_2
subtracao = valor_1 - valor_2
multiplicacao = valor_1 * valor_2
divisao = valor_1 / valor_2
potenciacao = valor_1 ** valor_2
print (f'o resultado vai ser: {resultado}')
print (f'o resultado vai ser: {subtracao}')
print (f'o resultado vai ser: {multiplicacao}')
print (f'o resultado vai ser: {potenciacao}')
# Out:
# o resultado vai ser: 9
# o resultado vai ser: 5
# o resultado vai ser: 14
# o resultado vai ser: 49

# %%
valor_1 = 15
valor_2 = 5
resultado = valor_1 + valor_2
subtracao = valor_1 - valor_2
multiplicacao = valor_1 * valor_2
divisao = valor_1 / valor_2
potenciacao = valor_1 ** valor_2
print (f'o resultado vai ser: {resultado}')
print (f'o resultado vai ser: {subtracao}')
print (f'o resultado vai ser: {multiplicacao}')
print (f'o resultado vai ser: {potenciacao}')
# Out:
# o resultado vai ser: 20
# o resultado vai ser: 10
# o resultado vai ser: 75
# o resultado vai ser: 759375

# %%
nome = input("Digite seu nome: ")
idade = input("Digite sua idade: ")
profissao = input("Digite sua profissão: ")

# Exibe as informações de forma organizada
print("\n===== INFORMAÇÕES DO USUÁRIO =====")
print(f"Nome      : {nome}")
print(f"Idade     : {idade} anos")
print(f"Profissão : {profissao}")
print("===================================")
